# %% [markdown]
# ## Agent?

# %%
from langchain_ollama import ChatOllama

model  = ChatOllama(model="ministral-3:3b")

# %%
# Langchain imports tools from community package

from langchain_community.tools import DuckDuckGoSearchRun

# %%
web_search_tool = DuckDuckGoSearchRun()

# %%
result = web_search_tool.invoke("top news in india today")

# %%
result
# Out:
# "8 hours ago · School Assembly News Headlines for January 21: From digital currency plans to climate warnings and global diplomacy, here are the key developments shaping India ... 10 hours ago · India Today LIVE TV 24X7 | Headlines | English News LIVE | Latest News · India Today TV Live: BJP National President Election | Tamil Nadu Explosion | Noida ... 2 days ago · 'An attack on women's dignity': Walls whitewashed after silhouettes defaced in Indian city ... Tripura student Anjel Chakma who was stabbed to death in Dehradun ... 30 Dec 2025 · Here are the major national, international, and sports updates that shaped the news cycle on December 30. · 1. INDIA HITS BACK AT PAKISTAN ON MINORITIES CHARGE. 4 hours ago · IndiGo fined ₹22 crore by DGCA over mass flight cancellations ... Denmark badminton player mocks Indian conditions via Instagram memes ... India becomes world's 2nd ..."
